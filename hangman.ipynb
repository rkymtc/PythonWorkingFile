# %%
import random

name=input("Adınızı Girin :")
print("Welcome to", name)

resim = ["""
+---+
|   | 
|       
|     
|      
|      
--------""","""
+---+
|   | 
|   O 
|     
|      
| 
--------""","""
+---+
|   | 
|   O 
|   |  
|      
| 
--------""","""
+---+
|   | 
|   O 
|  /|  
|      
|   
--------""","""
+---+
|   | 
|   O 
|  /|\ 
|      
|
--------""","""
+---+
|   | 
|   O 
|  /|\ 
|  /   
|
--------""","""
+---+
|   | 
|   O 
|  /|\  
|  / \  
|
--------"""]

while True:
    
    
    
    kelime = random.choice(["python", "global ai hub", "Turkish" ,"comment","statistic"])
    adim = 0
    tahmin = []
   
    
    while True:
        print(resim[adim])
        
        for i, char in enumerate(kelime):
            print(char if i in tahmin else "_"),
            
        cevap = input("Kelimeyi Tahmin Edin : ")
        
        if cevap == kelime:
            print("Kazandınız!")
            break
        else:
            while True:
                rastgele = random.randint(0, len(kelime))
                if not rastgele in tahmin:
                    tahmin.append(rastgele)
                    break
            
            adim += 1
        
        
        if adim >= len(resim):
            print("Kaybettiniz!",'/n'"Doğru Cevap:", kelime)
            break
        
    if not "y" == input("Tekrar Oynamak İstermisiniz? (y/n): "):
        break
# Out:
# Adınızı Girin :rukiye
# Welcome to rukiye
#
# +---+
# |   |
# |
# |
# |
# |
# --------
# _
# _
# _
# _
# _
# _
# _
# Kelimeyi Tahmin Edin : python
#
# +---+
# |   |
# |   O
# |
# |
# |
# --------
# _
# _
# r
# _
# _
# _
# _
# Kelimeyi Tahmin Edin : Turkish
# Kazandınız!
# Tekrar Oynamak İstermisiniz? (y/n): n
